# %% [markdown]
# ## Libraries

# %%
# !pip install python_speech_features
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python_speech_features
#   Downloading python_speech_features-0.6.tar.gz (5.6 kB)
# Building wheels for collected packages: python-speech-features
#   Building wheel for python-speech-features (setup.py) ... done
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-py3-none-any.whl size=5888 sha256=741a5676d2f019a3f83f6efa8f887ba1e4bef1dd4000f58f6722e2ef5489581b
#   Stored in directory: /root/.cache/pip/wheels/b0/0e/94/28cd6afa3cd5998a63eef99fe31777acd7d758f59cf24839eb
# Successfully built python-speech-features
# Installing collected packages: python-speech-features
# Successfully installed python-speech-features-0.6

# %%
import os 
import sys
import json  
import time
from   datetime                import date
  
import pandas                  as pd
import numpy                   as np 
import matplotlib.pyplot       as plt  
import seaborn                 as sn
from sklearn.metrics import confusion_matrix, accuracy_score

import tensorflow              as tf
from   tensorflow              import keras
from   tensorflow.keras        import layers, Input, backend
from   tensorflow.keras.layers import Dense, Activation, ZeroPadding2D, BatchNormalization, Conv2D, Permute
from   tensorflow.keras.layers import Lambda, Bidirectional, LSTM, GRU
from   tensorflow.keras.models import Model

from   scipy.io                import wavfile
from   python_speech_features  import mfcc, logfbank
import wave 

import itertools
import cProfile
from IPython.display            import Audio

# Colab and Drive Libraries
from   google.colab            import drive

# %% [markdown]
# ## Mounting Google's Drive (only for data purposes)

# %%
drive.mount('/content/drive') # to attempt to forcibly remount -> force_remount=True

# paths
FRA_PATH, FEDE_PATH = "/content/drive/MyDrive/University/HDA/HDA_Project/project", "/content/drive/MyDrive"

# Setting the working directory 
# os.chdir(FRA_PATH)
os.chdir(FEDE_PATH)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Utils

# %%
sys.path.append('./src/features')
sys.path.append('./src/data')
sys.path.append('./src/models')

# %%
import constants as cs
import feature_utils  as fs
import data_utils     as ds
import training_utils as ts

# %% [markdown]
# ## Graphic Settings

# %%
ds.set_dark_theme() if input("Are you in dark mode? y/n:   ").lower() == "y" else print("Hurts your eyes")
# Out:
# Are you in dark mode? y/n:   y

# %% [markdown]
# ## Filepaths

# %%
# Path of .npy files
BINARIES_PATH = "data/binaries/"

# %% [markdown]
# ## Loading Binaries

# %%
X_train = np.load(BINARIES_PATH + "X_train.npy")
X_valid = np.load(BINARIES_PATH + "X_valid.npy")
X_test = np.load(BINARIES_PATH + "X_test.npy")

y_train = np.load(BINARIES_PATH + "y_train.npy")
y_valid = np.load(BINARIES_PATH + "y_valid.npy")
y_test = np.load(BINARIES_PATH + "y_test.npy")

# %% [markdown]
# ### Extracting first 13 dimensions from them

# %%
X_train_envelope, X_valid_envelope, X_test_envelope = ds.envelope_coefficients(X_train), ds.envelope_coefficients(X_valid), ds.envelope_coefficients(X_test)

# %%
# checking dimensions
print("X_train: ", X_train_envelope.shape,  "\ny_train: ", y_train.shape, "\nX_valid: ", X_valid_envelope.shape, "\ny_valid: ", y_valid.shape, "\nX_test: ", X_test_envelope.shape,  "\ny_test: ",  y_test.shape)
# Out:
# X_train:  (30769, 13, 99)
# y_train:  (30769,)
# X_valid:  (3703, 13, 99)
# y_valid:  (3703,)
# X_test:  (4074, 13, 99)
# y_test:  (4074,)

# %%
X_train_envelope, y_train = ts.reshape(X_train_envelope, y_train)
X_valid_envelope, y_valid = ts.reshape(X_valid_envelope, y_valid)
X_test_envelope, y_test = ts.reshape(X_test_envelope, y_test)

# %%
# checking dimensions
print("X_train: ", X_train_envelope.shape,  "\ny_train: ", y_train.shape, "\nX_valid: ", X_valid_envelope.shape, "\ny_valid: ", y_valid.shape, "\nX_test: ", X_test_envelope.shape,  "\ny_test: ",  y_test.shape)
# Out:
# X_train:  (30769, 13, 99, 1)
# y_train:  (30769, 1)
# X_valid:  (3703, 13, 99, 1)
# y_valid:  (3703, 1)
# X_test:  (4074, 13, 99, 1)
# y_test:  (4074, 1)

# %% [markdown]
# # Recurrent Neural Network Architecture
#
# The main sequence on which we will base the training of the neural networks is:
#
# 1. Build the model
# 2. Train the model
# 3. Evaluate the model
# 4. Plot performance of the model
# 5. Predictions and confusion matrix of the model
# 6. Save the model

# %%
# Hyperparameters 
EPOCHS = 100
BATCH_SIZE = 32
PATIENCE = 10

# Parameters
INPUT_SHAPE = np.shape(X_train_envelope[-1,:,:,:])
NUM_CATEGORIES = cs.num_categories_reduced
LABELS_10_CLASSES = cs.labels_10_classes

# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
# ## Long Short-Term Memory (LSTM)

# %% [markdown]
# ### 1. Build the model

# %%
# Create network
lstm_name = 'lstm_model_reduced'
lstm_model = ts.rnn_architecture(name = lstm_name, input_shape = INPUT_SHAPE, rnn = 'LSTM', num_classes = NUM_CATEGORIES)
# Out:
# Model: "lstm_model_reduced"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 13, 99, 1)]       0
#
#  permute (Permute)           (None, 99, 13, 1)         0
#
#  batch_norm0 (BatchNormaliza  (None, 99, 13, 1)        4
#  tion)
#
#  conv0 (Conv2D)              (None, 99, 13, 10)        60
#
#  batch_norm1 (BatchNormaliza  (None, 99, 13, 10)       40
#  tion)
#
#  conv1 (Conv2D)              (None, 99, 13, 1)         51
#
#  batch_norm2 (BatchNormaliza  (None, 99, 13, 1)        4
#  tion)
#
#  squeeze_last_dim (Lambda)   (None, 99, 13)            0
#
#  bidir_LSTM0 (Bidirectional)  (None, 99, 128)          39936
#
#  bidir_LSTM1 (Bidirectional)  (None, 128)              98816
#
#  fc0_relu (Dense)            (None, 64)                8256
#
#  fc1_relu (Dense)            (None, 32)                2080
#
#  fc2_softmax (Dense)         (None, 10)                330
#
# =================================================================
# Total params: 149,577
# Trainable params: 149,553
# Non-trainable params: 24
# _________________________________________________________________

# %% [markdown]
# ### 2. Train the model

# %%
# train network
history = ts.rnn_training(model = lstm_model, 
                model_name = lstm_name,
                epochs = EPOCHS, 
                batch_size = BATCH_SIZE, 
                patience = PATIENCE, 
                X_train = X_train_envelope, 
                y_train = y_train, 
                X_validation = X_valid_envelope, 
                y_validation = y_valid)
# Out:
# Epoch 1/100
# 962/962 [==============================] - 38s 23ms/step - loss: 1.4000 - sparse_categorical_accuracy: 0.5004 - val_loss: 0.7953 - val_sparse_categorical_accuracy: 0.7372 - lr: 0.0010
# Epoch 2/100
# 962/962 [==============================] - 21s 21ms/step - loss: 0.5682 - sparse_categorical_accuracy: 0.8123 - val_loss: 0.4303 - val_sparse_categorical_accuracy: 0.8585 - lr: 0.0010
# Epoch 3/100
# 962/962 [==============================] - 20s 21ms/step - loss: 0.3740 - sparse_categorical_accuracy: 0.8754 - val_loss: 0.3678 - val_sparse_categorical_accuracy: 0.8760 - lr: 0.0010
# Epoch 4/100
# 962/962 [==============================] - 20s 21ms/step - loss: 0.2844 - sparse_categorical_accuracy: 0.9047 - val_loss: 0.3311 - val_sparse_categorical_accuracy: 0.8895 - lr: 0.0010
# Epoch 5/100
# 962/962 [==============================] - 20s 21ms/step - loss: 0.2208 - sparse_categorical_accuracy: 0.9259 - val_loss: 0.2279 - val_sparse_categorical_accuracy: 0.9252 - lr: 0.0010
# Epoch 6/100
# 962/962 [==============================] - 21s 21ms/step - loss: 0.1750 - sparse_categorical_accuracy: 0.9398 - val_loss: 0.2107 - val_sparse_categorical_accuracy: 0.9319 - lr: 0.0010
# Epoch 7/100
# 962/962 [==============================] - 20s 21ms/step - loss: 0.1498 - sparse_categorical_accuracy: 0.9500 - val_loss: 0.2062 - val_sparse_categorical_accuracy: 0.9341 - lr: 0.0010
# Epoch 8/100
# 962/962 [==============================] - 20s 21ms/step - loss: 0.1253 - sparse_categorical_accuracy: 0.9571 - val_loss: 0.2065 - val_sparse_categorical_accuracy: 0.9317 - lr: 0.0010
# Epoch 9/100
# 962/962 [==============================] - 19s 20ms/step - loss: 0.1142 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.2111 - val_sparse_categorical_accuracy: 0.9400 - lr: 0.0010
# Epoch 10/100
# 962/962 [==============================] - 20s 20ms/step - loss: 0.0973 - sparse_categorical_accuracy: 0.9666 - val_loss: 0.2193 - val_sparse_categorical_accuracy: 0.9357 - lr: 0.0010
# Epoch 11/100
# 962/962 [==============================] - 20s 20ms/step - loss: 0.0864 - sparse_categorical_accuracy: 0.9693 - val_loss: 0.2200 - val_sparse_categorical_accuracy: 0.9325 - lr: 0.0010
# Epoch 12/100
# 962/962 [==============================] - 20s 20ms/step - loss: 0.0790 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.2364 - val_sparse_categorical_accuracy: 0.9333 - lr: 0.0010
# Epoch 13/100
# 962/962 [==============================] - 20s 21ms/step - loss: 0.0725 - sparse_categorical_accuracy: 0.9742 - val_loss: 0.2582 - val_sparse_categorical_accuracy: 0.9265 - lr: 0.0010
# Epoch 14/100
# 962/962 [==============================] - 21s 22ms/step - loss: 0.0664 - sparse_categorical_accuracy: 0.9775 - val_loss: 0.2309 - val_sparse_categorical_accuracy: 0.9363 - lr: 0.0010
# Epoch 15/100
# 962/962 [==============================] - 20s 21ms/step - loss: 0.0567 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.2440 - val_sparse_categorical_accuracy: 0.9414 - lr: 0.0010
# Epoch 16/100
# 962/962 [==============================] - 20s 21ms/step - loss: 0.0558 - sparse_categorical_accuracy: 0.9807 - val_loss: 0.2613 - val_sparse_categorical_accuracy: 0.9319 - lr: 0.0010
# Epoch 17/100
# 960/962 [============================>.] - ETA: 0s - loss: 0.0523 - sparse_categorical_accuracy: 0.9818
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 962/962 [==============================] - 20s 21ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9818 - val_loss: 0.2848 - val_sparse_categorical_accuracy: 0.9314 - lr: 0.0010
# Epoch 18/100
# 962/962 [==============================] - 20s 20ms/step - loss: 0.0302 - sparse_categorical_accuracy: 0.9904 - val_loss: 0.2224 - val_sparse_categorical_accuracy: 0.9438 - lr: 1.0000e-04
# Epoch 19/100
# 962/962 [==============================] - 20s 20ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.2303 - val_sparse_categorical_accuracy: 0.9446 - lr: 1.0000e-04
# Epoch 20/100
# 962/962 [==============================] - 19s 20ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.2434 - val_sparse_categorical_accuracy: 0.9457 - lr: 1.0000e-04
# Epoch 21/100
# 962/962 [==============================] - 19s 20ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.2547 - val_sparse_categorical_accuracy: 0.9454 - lr: 1.0000e-04
# Epoch 22/100
# 962/962 [==============================] - 19s 20ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.2696 - val_sparse_categorical_accuracy: 0.9457 - lr: 1.0000e-04
# Epoch 23/100
# 962/962 [==============================] - 19s 20ms/step - loss: 0.0111 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.2811 - val_sparse_categorical_accuracy: 0.9452 - lr: 1.0000e-04
# Epoch 24/100
# 962/962 [==============================] - 19s 20ms/step - loss: 0.0096 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.2960 - val_sparse_categorical_accuracy: 0.9457 - lr: 1.0000e-04
# Epoch 25/100
# 962/962 [==============================] - 19s 20ms/step - loss: 0.0080 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.3114 - val_sparse_categorical_accuracy: 0.9438 - lr: 1.0000e-04
# Epoch 26/100
# 962/962 [==============================] - 19s 20ms/step - loss: 0.0065 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.3242 - val_sparse_categorical_accuracy: 0.9441 - lr: 1.0000e-04
# Epoch 27/100
# 960/962 [============================>.] - ETA: 0s - loss: 0.0057 - sparse_categorical_accuracy: 0.9983
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 962/962 [==============================] - 19s 20ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.3401 - val_sparse_categorical_accuracy: 0.9433 - lr: 1.0000e-04
# Epoch 28/100
# 962/962 [==============================] - 20s 21ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.3380 - val_sparse_categorical_accuracy: 0.9446 - lr: 1.0000e-05
# Epoch 29/100
# 962/962 [==============================] - 19s 20ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.3383 - val_sparse_categorical_accuracy: 0.9454 - lr: 1.0000e-05
# Epoch 30/100
# 960/962 [============================>.] - ETA: 0s - loss: 0.0034 - sparse_categorical_accuracy: 0.9993Restoring model weights from the end of the best epoch: 20.
# 962/962 [==============================] - 19s 20ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.3397 - val_sparse_categorical_accuracy: 0.9452 - lr: 1.0000e-05
# Epoch 30: early stopping

# %% [markdown]
# ### 3. Evaluate the model

# %%
# evaluate network on test set
test_loss, test_acc = lstm_model.evaluate(X_test_envelope, y_test)
print("\nTest loss: {}, test accuracy: {}".format(test_loss, 100*test_acc))
# Out:
# 128/128 [==============================] - 1s 10ms/step - loss: 0.2499 - sparse_categorical_accuracy: 0.9458
#
# Test loss: 0.24990960955619812, test accuracy: 94.57535743713379

# %% [markdown]
# ### 4. Plot performance of the model

# %%
# plot the performances
ts.plot_history(history, lstm_name, filename='accuracy_loss_{}.png'.format(lstm_name))

# %% [markdown]
# ### 5. Predictions and confusion matrix of the model

# %%
y_pred = lstm_model.predict(X_test_envelope, verbose=0)
matrix  = confusion_matrix(y_test, y_pred.argmax(axis=1))
ts.plot_confusion_matrix(matrix, LABELS_10_CLASSES)

# %%
percentages_misclassified_samples = np.ones_like(matrix)
sums = np.sum(matrix, axis = 1)

for i in range(matrix.shape[0]):
    percentages_misclassified_samples[i] = matrix[i] / sums[i] * 100

# percentages_misclassified_samples
ts.plot_confusion_matrix(percentages_misclassified_samples, LABELS_10_CLASSES, title = "Percentages of misclassified samples per class", display_metrics = False)

# %% [markdown]
# Prediction time

# %%
ts.prediction_time(lstm_model, X_test_envelope)
# Out:
# Average prediction time (ms): 50.56595906347766

# %% [markdown]
# ### 6. Save the model

# %%
# save model
lstm_model.save('{}.h5'.format(lstm_name))

# %% [markdown]
# ## Gated Recurrent Unit (GRU)

# %% [markdown]
# ### 1. Build the model

# %%
# Create network
gru_name = 'gru_model_reduced'
gru_model = ts.rnn_architecture(name = gru_name, input_shape = INPUT_SHAPE, rnn = 'GRU', num_classes = NUM_CATEGORIES)
# Out:
# Model: "gru_model_reduced"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 13, 99, 1)]       0
#
#  permute_2 (Permute)         (None, 99, 13, 1)         0
#
#  batch_norm0 (BatchNormaliza  (None, 99, 13, 1)        4
#  tion)
#
#  conv0 (Conv2D)              (None, 99, 13, 10)        60
#
#  batch_norm1 (BatchNormaliza  (None, 99, 13, 10)       40
#  tion)
#
#  conv1 (Conv2D)              (None, 99, 13, 1)         51
#
#  batch_norm2 (BatchNormaliza  (None, 99, 13, 1)        4
#  tion)
#
#  squeeze_last_dim (Lambda)   (None, 99, 13)            0
#
#  bidir_GRU1 (Bidirectional)  (None, 99, 128)           30336
#
#  bidir_GRU2 (Bidirectional)  (None, 128)               74496
#
#  fc0_relu (Dense)            (None, 64)                8256
#
#  fc1_relu (Dense)            (None, 32)                2080
#
#  fc2_softmax (Dense)         (None, 10)                330
#
# =================================================================
# Total params: 115,657
# Trainable params: 115,633
# Non-trainable params: 24
# _________________________________________________________________

# %% [markdown]
# ### 2. Train the model

# %%
# train network
history = ts.rnn_training(model = gru_model, 
                model_name = gru_name,
                epochs = EPOCHS, 
                batch_size = BATCH_SIZE, 
                patience = PATIENCE, 
                X_train = X_train_envelope, 
                y_train = y_train, 
                X_validation = X_valid_envelope, 
                y_validation = y_valid)
# Out:
# Epoch 1/100
# 241/241 [==============================] - 14s 34ms/step - loss: 1.9166 - sparse_categorical_accuracy: 0.2827 - val_loss: 1.2909 - val_sparse_categorical_accuracy: 0.5625 - lr: 0.0010
# Epoch 2/100
# 241/241 [==============================] - 7s 27ms/step - loss: 0.5736 - sparse_categorical_accuracy: 0.8004 - val_loss: 0.4162 - val_sparse_categorical_accuracy: 0.8625 - lr: 0.0010
# Epoch 3/100
# 241/241 [==============================] - 7s 27ms/step - loss: 0.3346 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.2978 - val_sparse_categorical_accuracy: 0.8979 - lr: 0.0010
# Epoch 4/100
# 241/241 [==============================] - 7s 27ms/step - loss: 0.2385 - sparse_categorical_accuracy: 0.9202 - val_loss: 0.2428 - val_sparse_categorical_accuracy: 0.9171 - lr: 0.0010
# Epoch 5/100
# 241/241 [==============================] - 7s 28ms/step - loss: 0.1858 - sparse_categorical_accuracy: 0.9374 - val_loss: 0.2189 - val_sparse_categorical_accuracy: 0.9252 - lr: 0.0010
# Epoch 6/100
# 241/241 [==============================] - 6s 27ms/step - loss: 0.1481 - sparse_categorical_accuracy: 0.9495 - val_loss: 0.2648 - val_sparse_categorical_accuracy: 0.9087 - lr: 0.0010
# Epoch 7/100
# 241/241 [==============================] - 6s 27ms/step - loss: 0.1241 - sparse_categorical_accuracy: 0.9579 - val_loss: 0.2194 - val_sparse_categorical_accuracy: 0.9292 - lr: 0.0010
# Epoch 8/100
# 241/241 [==============================] - 7s 28ms/step - loss: 0.1043 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.2098 - val_sparse_categorical_accuracy: 0.9333 - lr: 0.0010
# Epoch 9/100
# 241/241 [==============================] - 7s 29ms/step - loss: 0.0902 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.2298 - val_sparse_categorical_accuracy: 0.9311 - lr: 0.0010
# Epoch 10/100
# 241/241 [==============================] - 6s 27ms/step - loss: 0.0707 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.2600 - val_sparse_categorical_accuracy: 0.9265 - lr: 0.0010
# Epoch 11/100
# 241/241 [==============================] - 6s 26ms/step - loss: 0.0692 - sparse_categorical_accuracy: 0.9766 - val_loss: 0.2446 - val_sparse_categorical_accuracy: 0.9322 - lr: 0.0010
# Epoch 12/100
# 241/241 [==============================] - 6s 27ms/step - loss: 0.0550 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.2611 - val_sparse_categorical_accuracy: 0.9303 - lr: 0.0010
# Epoch 13/100
# 241/241 [==============================] - 6s 26ms/step - loss: 0.0490 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.3148 - val_sparse_categorical_accuracy: 0.9268 - lr: 0.0010
# Epoch 14/100
# 241/241 [==============================] - 6s 27ms/step - loss: 0.0488 - sparse_categorical_accuracy: 0.9831 - val_loss: 0.3006 - val_sparse_categorical_accuracy: 0.9260 - lr: 0.0010
# Epoch 15/100
# 241/241 [==============================] - 6s 27ms/step - loss: 0.0390 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.2999 - val_sparse_categorical_accuracy: 0.9311 - lr: 0.0010
# Epoch 16/100
# 241/241 [==============================] - 6s 26ms/step - loss: 0.0391 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.2989 - val_sparse_categorical_accuracy: 0.9309 - lr: 0.0010
# Epoch 17/100
# 241/241 [==============================] - 6s 27ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.3169 - val_sparse_categorical_accuracy: 0.9325 - lr: 0.0010
# Epoch 18/100
# 241/241 [==============================] - ETA: 0s - loss: 0.0241 - sparse_categorical_accuracy: 0.9921Restoring model weights from the end of the best epoch: 8.
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 241/241 [==============================] - 6s 26ms/step - loss: 0.0241 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.3493 - val_sparse_categorical_accuracy: 0.9303 - lr: 0.0010
# Epoch 18: early stopping

# %% [markdown]
# ### 3. Evaluate the model

# %%
# evaluate network on test set
test_loss, test_acc = gru_model.evaluate(X_test_envelope, y_test)
print("\nTest loss: {}, test accuracy: {}".format(test_loss, 100*test_acc))
# Out:
# 128/128 [==============================] - 1s 10ms/step - loss: 0.2005 - sparse_categorical_accuracy: 0.9386
#
# Test loss: 0.200510635972023, test accuracy: 93.86352300643921

# %% [markdown]
# ### 4. Plot performance of the model

# %%
# plot the performances
ts.plot_history(history, gru_name, filename='accuracy_loss_{}.png'.format(gru_name))

# %% [markdown]
# ### 5. Predictions and confusion matrix of the model

# %%
y_pred = gru_model.predict(X_test_envelope, verbose=0)
matrix  = confusion_matrix(y_test, y_pred.argmax(axis=1))
ts.plot_confusion_matrix(matrix, LABELS_10_CLASSES)

# %%
percentages_misclassified_samples = np.ones_like(matrix)
sums = np.sum(matrix, axis = 1)

for i in range(matrix.shape[0]):
    percentages_misclassified_samples[i] = matrix[i] / sums[i] * 100

# percentages_misclassified_samples
ts.plot_confusion_matrix(percentages_misclassified_samples, LABELS_10_CLASSES, title = "Percentages of misclassified samples per class", display_metrics = False)

# %% [markdown]
# Prediction time

# %%
ts.prediction_time(gru_model, X_test_envelope)
# Out:
# Average prediction time (ms): 44.271489715950715

# %% [markdown]
# ### 6. Save the model

# %%
# save model
gru_model.save('{}.h5'.format(gru_name))
